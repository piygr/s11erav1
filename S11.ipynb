# %%
# !git clone https://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@github.com/piygr/mainErav1.git
# Out:
# Cloning into 's11erav1'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 41 (delta 19), reused 31 (delta 11), pack-reused 0
# Receiving objects: 100% (41/41), 14.71 KiB | 14.71 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# !git pull origin main
# Out:
# From https://github.com/piygr/s11erav1
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# %cd s11erav1
# !ls
# Out:
# /content/s11erav1
# dataset.py  models     requirements.txt  utils.py
# main.py     README.md  transforms.py

# %%
# !pip install torch_lr_finder
# !pip install grad-cam
from main import *
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 53.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for grad-cam: filename=grad_cam-1.4.8-py3-none-any.whl size=38247 sha256=5f9d6036205cfbf5c11ed1a1335549fae12dcea392d8d6f3e0207d4b1c8a0047
#   Stored in directory: /root/.cache/pip/wheels/f8/04/36/94ff3c8a4215826a21946b34c01180817e606989fdf53f7cd6
# Successfully built grad-cam
# ...
# /content/s11erav1/utils.py:2: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# CUDA Available? True
# ...
# 100%|██████████| 170498071/170498071 [00:14<00:00, 11929310.42it/s]
# Extracting ../data/cifar-10-python.tar.gz to ../data
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from main import init

# %%
init(show_model_summary=True, find_lr=False)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
# ...

# %%
train_model(num_epochs=20)
# Out:
# Epoch 1 LR [1.8300000000000011e-06]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 1.8973, Accuracy: 3039/10000 (30.39%)
#
# Epoch 2 LR [1.4006520508580466e-05]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 1.6160, Accuracy: 4137/10000 (41.37%)
#
# Epoch 3 LR [4.726252346069751e-05]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 1.2783, Accuracy: 5321/10000 (53.21%)
#
# Epoch 4 LR [9.265740275203222e-05]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 1.2009, Accuracy: 5779/10000 (57.79%)
#
# Epoch 5 LR [0.00013798711403362012]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 1.1711, Accuracy: 5848/10000 (58.48%)
#
# Epoch 6 LR [0.00017106513284626188]
#   0%|          | 0/98 [00:00<?, ?it/s]
# Test set: Average loss: 1.0775, Accuracy: 6295/10000 (62.95%)
#
# Epoch 7 LR [0.00018299976015039937]
#   0%|          | 0/98 [00:00<?, ?it/s]
# ...

# %%
from dataset import get_data_label_name
from utils import test_correct_pred, test_incorrect_pred, np
import matplotlib.pyplot as plt
from pytorch_grad_cam import GradCAM, HiResCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image




plot_incorrect_preds(dataset_mean, dataset_std, count=15)
plot_grad_cam(model, dataset_mean, dataset_std, count=15, correct=False)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
from utils import plot_grad_cam

# %%
target_layers = [model.layer3[-1]]

# %%
from pytorch_grad_cam import GradCAM, HiResCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image
cam = GradCAM(model=model, target_layers=target_layers, use_cuda=torch.cuda.is_available())

# %%
from utils import test_correct_pred, test_incorrect_pred
from utils import np, get_data_label_name
import matplotlib.pyplot as plt
MEAN = torch.tensor(dataset_mean)
STD = torch.tensor(dataset_std)
for i in range(5):
  plt.subplot(int(5 / 5), 5, i + 1)
  #plt.tight_layout()
  pred_dict = test_incorrect_pred
  #print(test_correct_pred)
  targets = [ClassifierOutputTarget( pred_dict['ground_truths'][i].item() )]

  grayscale_cam = cam(input_tensor=pred_dict['images'][i][None, :], targets=targets)

  grayscale_cam = grayscale_cam[0, :]

  x = pred_dict['images'][i] * STD[:, None, None] + MEAN[:, None, None]

  img_tensor = np.array(x, np.int16).transpose(1, 2, 0)

  visualization = show_cam_on_image(img_tensor, grayscale_cam, use_rgb=True)

  image = np.array(255 * x, np.int16).transpose(1, 2, 0)
  plt.imshow(image)
  plt.imshow(visualization, alpha=0.4)
  plt.xticks([])
  plt.yticks([])

  title = get_data_label_name(pred_dict['ground_truths'][i].item()) + ' / ' + \
  get_data_label_name(pred_dict['predicted_vals'][i].item())
  plt.title(title)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
